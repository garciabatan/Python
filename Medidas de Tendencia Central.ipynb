# %% [markdown]
# ## Tipos de Datos
#
# Vamos a trabajar con los siguientes tipos de datos:
#
# * **CUANTITATIVOS** (numéricos)
#     * continuos
#     * discretos
#
#
# * **CUALITATIVOS** (categóricos)
#     * ordinales
#     * nominales
#
# En estadística, una variable es un atributo que describe una entidad, como una persona, un lugar o una cosa. El valor de esa variable puede variar de una entidad a otra.

# %% [markdown]
# ### Como instalar librerias en python?
#
# **Para instalar librerias sera mediante el comando "pip install xxxxxx" en la terminal**
#
# pip install pandas
#
# pip install numpy
#
# pip install matplotlib
#
# pip install seaborn
#
# pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt

# %% [markdown]
# ## Datos Cuantitativos

# %% [markdown]
# ### Datos Continuos

# %%
alturas = np.random.normal(1.75, 0.15, 100)

pesos = np.random.normal(80,30,100)

# %%
#print(alturas)

plt.hist(alturas, bins=50, density=True, color="pink", alpha = 0.7)
# Out:
# (array([4.01453602e-04, 1.60581441e-03, 2.40872161e-03, 2.40872161e-03,
#         5.62035043e-03, 1.12407009e-02, 1.68610513e-02, 2.48901233e-02,
#         4.57657107e-02, 7.38674628e-02, 1.18027359e-01, 1.69413420e-01,
#         2.53718677e-01, 3.53680624e-01, 5.03422817e-01, 6.40719949e-01,
#         8.37432214e-01, 1.07067676e+00, 1.35129283e+00, 1.61384348e+00,
#         1.87719704e+00, 2.11124449e+00, 2.31277420e+00, 2.51028937e+00,
#         2.54762456e+00, 2.65160104e+00, 2.62831673e+00, 2.55204055e+00,
#         2.36616753e+00, 2.15098840e+00, 1.90810897e+00, 1.68048478e+00,
#         1.38140185e+00, 1.14012823e+00, 8.82395018e-01, 6.74843505e-01,
#         5.17875147e-01, 3.53680624e-01, 2.74594264e-01, 1.89084647e-01,
#         1.25253524e-01, 8.55096173e-02, 4.93787931e-02, 2.97075666e-02,
#         2.40872161e-02, 8.83197925e-03, 6.82471124e-03, 3.21162882e-03,
#         3.21162882e-03, 1.20436081e-03]),
# ...

# %% [markdown]
# ### Datos Discretos

# %%
monedas = np.random.randint(500, size=10)

campeonatos = np.random.randint(12, size=32)

print(campeonatos)
print(monedas)
# Out:
# [ 5  7  8  1  1  3  7  3  8  0  2  1 10  8  0  6  0  3  8  7  4  7  2  7
#   1  7  6  0  1  9  5  5]
# [188 477 211 393 107 323  64 161 405 238]

# %% [markdown]
# ## Datos cualitativos

# %% [markdown]
# ### Datos Ordinales

# %%
# Cualitativos Nominales

colores = ['azul', 'amarillo', 'verde', 'rojo', 'blanco', 'negro', 'naranja', 'gris', 'morado']
colores
# Out:
# ['azul',
#  'amarillo',
#  'verde',
#  'rojo',
#  'blanco',
#  'negro',
#  'naranja',
#  'gris',
#  'morado']

# %% [markdown]
# ### Datos Nominales

# %%
# Cualitativos Ordinales

calidad = ['pésimo', 'muy malo', 'malo', 'regular', 'bueno', 'muy bueno', 'excelente']
calidad
# Out:
# ['pésimo', 'muy malo', 'malo', 'regular', 'bueno', 'muy bueno', 'excelente']

# %%
datos = ['uno','uno','uno','dos','dos','tres']

# %%
type(datos)
# Out:
# list

# %%
len(datos)
# Out:
# 6

# %%
np.unique(datos,return_counts=True)
# Out:
# (array(['dos', 'tres', 'uno'], dtype='<U4'), array([2, 1, 3]))

# %% [markdown]
# ## Medidas Tendencia Central

# %%
goles = [0,3,3,0,8,1,1,0,0,9,5]

# %%
np.mean(goles)
# Out:
# 2.727272727272727

# %%
np.sort(goles)
# Out:
# array([0, 0, 0, 0, 1, 1, 3, 3, 5, 8, 9])

# %%
np.median(goles)
# Out:
# 1.0

# %%
st.mode(goles)
# Out:
# 0

# %% [markdown]
# ## Calculo de Cuantiles

# %%
alturas = np.random.normal(1.75, 0.15, 100000)

np.quantile(alturas, [0, 1/3, 2/3, 1])
# Out:
# array([1.11196575, 1.68473521, 1.81421135, 2.35743969])

# %%
cuantiles = [(2, "Mediana"),
             (3, "Terciles"),
             (4, "Cuartiles"),
             (5, "Quintiles"),
             (10, "Deciles"),
             (100, "Percentiles")]

cortes = []
for cuantil in cuantiles:
    corte = []
    valor = 0
    for i in range(cuantil[0]-1):
        valor += 1/cuantil[0]
        corte.append(valor)         
    cortes.append(corte)

for i in range(len(cuantiles)):
    plt.figure(figsize=(7.5, 5))
    plt.title(cuantiles[i][1], size=22)
    plt.ylabel("Frecuencia", size=16)
    plt.xlabel("Alturas", size=16)
    plt.hist(alturas, 100, label="altura", color="pink")
    #print(np.quantile(alturas, [0] + cortes[i] + [1]))
    for corte in cortes[i]:
        plt.axvline(x = np.quantile(alturas, corte), label="%.2f" % corte, linewidth=3)
    if i < len(cuantiles) - 1:
        plt.legend()
    plt.show()
    print("\n"*4)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
